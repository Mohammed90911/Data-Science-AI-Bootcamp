# %% [markdown]
# # Exploratory Analysis

# %%
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import os

# %% [markdown]
# ## Get the data

# %%
import sys
from pathlib import Path

olist_parent = Path.home() / "code/moha/03-Decision-Science/01-Statistical-Inference/data-context-and-setup"
if not olist_parent.exists():
    olist_parent = Path.home() / "code/Mohammed90911/03-Decision-Science/01-Statistical-Inference/data-context-and-setup"

if str(olist_parent) not in sys.path:
    sys.path.insert(0, str(olist_parent))

from olist.data import Olist
data = Olist().get_data()

# %% [markdown]
# Each transaction on the Olist ecommerce platform is characterized by:
# - a `customer_id`, that would buy...
# - various`product_id`...
# - to a `seller_id`...
# - and leaves a `review_id`...
# - all this belonging to an `order_id`

# %% [markdown]
# ## Investigate the cardinalities of your various DataFrames

# %% [markdown]
# ❓ **How many unique `orders`, `reviews`, `sellers`, `products` and `customers` are there ?**

# %%
{
    'orders': data['orders']['order_id'].nunique(),
    'reviews': data['order_reviews']['review_id'].nunique(),
    'sellers': data['sellers']['seller_id'].nunique(),
    'products': data['products']['product_id'].nunique(),
    'customers': data['customers']['customer_id'].nunique(),
}
# Out:
# {'orders': 99441,
#  'reviews': 98410,
#  'sellers': 3095,
#  'products': 32951,
#  'customers': 99441}

# %% [markdown]
# ❓ **How many reviews are there per order? Do we have reviews for all orders ?**
# <details>
#     <summary markdown='span'>Hints</summary>
#
# This info is not directly accessible in your individual csv. You'll need to merge tables to find out. Think about which kind of merge you need.
#
# Not sure which tables you need? Go back to your ERD to find out.
#
# To find out the number of reviews: count the number of reviews per `order_id`, and plot a histogram. You can use `.hist()` on a Pandas series.
# </details>

# %%
data['order_reviews']['order_id'].value_counts().value_counts()
# Out:
# count
# 1    98126
# 2      543
# 3        4
# Name: count, dtype: int64

# %% [markdown]
# 🧪 **Test your code below**

# %% [markdown]
# Store the number of orders with missing reviews as `int` in a variable named `n_missing_reviews`

# %%
n_missing_reviews = data['orders']['order_id'].nunique() - data['order_reviews']['order_id'].nunique()
n_missing_reviews
# Out:
# 768

# %%
from nbresult import ChallengeResult

result = ChallengeResult('exploratory',
    n=n_missing_reviews
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /home/moha/.pyenv/versions/3.12.9/envs/lewagon/bin/python
# cachedir: .pytest_cache
# rootdir: /home/moha/code/Mohammed90911/03-Decision-Science/01-Statistical-Inference/data-exploratory-analysis/tests
# plugins: anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_exploratory.py::TestExploratory::test_n_missing_reviews PASSED      [100%]
#
# ============================== 1 passed in 0.05s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/exploratory.pickle
#
# git commit -m 'Completed exploratory step'
#
# git push origin master
